# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib as mp
import matplotlib.pyplot as plt

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
pd.read_excel('content_based_recommendation_dataset.xlsx')
# Out:
#       Number of clicks on similar products  \
# 0                                       12
# 1                                        8
# 2                                       25
# 3                                        6
# 4                                       18
# ...                                    ...
# 1469                                     5
# 1470                                    37
# 1471                                    22
# 1472                                    40
# 1473                                    12
#
#       Number of similar products purchased so far  \
# 0                                               4
# 1                                               2
# 2                                              10
# 3                                               1
# 4                                               5
# ...                                           ...
# 1469                                            1
# ...

# %%
DS = pd.read_excel('content_based_recommendation_dataset.xlsx')

# %%
DS.head()
# Out:
#    Number of clicks on similar products  \
# 0                                    12
# 1                                     8
# 2                                    25
# 3                                     6
# 4                                    18
#
#    Number of similar products purchased so far  \
# 0                                            4
# 1                                            2
# 2                                           10
# 3                                            1
# 4                                            5
#
#    Average rating given to similar products  Gender  \
# 0                                       4.2    male
# 1                                       3.8  female
# 2                                       4.5  female
# 3                                       2.1  female
# 4                                       4.7    male
#
#    Median purchasing price (in rupees)  Rating of the product  \
# ...

# %% [markdown]
# Task 1

# %%
DS.head()
# Out:
#    Number of clicks on similar products  \
# 0                                    12
# 1                                     8
# 2                                    25
# 3                                     6
# 4                                    18
#
#    Number of similar products purchased so far  \
# 0                                            4
# 1                                            2
# 2                                           10
# 3                                            1
# 4                                            5
#
#    Average rating given to similar products  Gender  \
# 0                                       4.2    male
# 1                                       3.8  female
# 2                                       4.5  female
# 3                                       2.1  female
# 4                                       4.7    male
#
#    Median purchasing price (in rupees)  Rating of the product  \
# ...

# %% [markdown]
# Task 2

# %%
DS.shape
# Out:
# (1474, 13)

# %%
DS.columns
# Out:
# Index(['Number of clicks on similar products',
#        'Number of similar products purchased so far',
#        'Average rating given to similar products', 'Gender',
#        'Median purchasing price (in rupees)', 'Rating of the product',
#        'Brand of the product', 'Customer review sentiment score (overall)',
#        'Price of the product', 'Holiday', 'Season', 'Geographical locations',
#        'Probability for the product to be recommended to the person'],
#       dtype='object')

# %% [markdown]
# Task 3

# %%
DS.dtypes
# Out:
# Number of clicks on similar products                             int64
# Number of similar products purchased so far                      int64
# Average rating given to similar products                       float64
# Gender                                                          object
# Median purchasing price (in rupees)                              int64
# Rating of the product                                          float64
# Brand of the product                                            object
# Customer review sentiment score (overall)                      float64
# Price of the product                                             int64
# Holiday                                                         object
# Season                                                          object
# Geographical locations                                          object
# Probability for the product to be recommended to the person    float64
# dtype: object

# %% [markdown]
# Task 4

# %%
DS.isnull().sum()
# Out:
# Number of clicks on similar products                           0
# Number of similar products purchased so far                    0
# Average rating given to similar products                       0
# Gender                                                         0
# Median purchasing price (in rupees)                            0
# Rating of the product                                          0
# Brand of the product                                           0
# Customer review sentiment score (overall)                      0
# Price of the product                                           0
# Holiday                                                        0
# Season                                                         0
# Geographical locations                                         0
# Probability for the product to be recommended to the person    0
# dtype: int64

# %% [markdown]
# task 5 there is no missing data

# %%
DS.notnull()
# Out:
#       Number of clicks on similar products  \
# 0                                     True
# 1                                     True
# 2                                     True
# 3                                     True
# 4                                     True
# ...                                    ...
# 1469                                  True
# 1470                                  True
# 1471                                  True
# 1472                                  True
# 1473                                  True
#
#       Number of similar products purchased so far  \
# 0                                            True
# 1                                            True
# 2                                            True
# 3                                            True
# 4                                            True
# ...                                           ...
# 1469                                         True
# ...

# %% [markdown]
# task 6

# %%
DS.duplicated().sum()
# Out:
# np.int64(456)

# %%
DS = DS.drop_duplicates()

# %%
DS
# Out:
#       Number of clicks on similar products  \
# 0                                       12
# 1                                        8
# 2                                       25
# 3                                        6
# 4                                       18
# ...                                    ...
# 1469                                     5
# 1470                                    37
# 1471                                    22
# 1472                                    40
# 1473                                    12
#
#       Number of similar products purchased so far  \
# 0                                               4
# 1                                               2
# 2                                              10
# 3                                               1
# 4                                               5
# ...                                           ...
# 1469                                            1
# ...

# %% [markdown]
# task 7

# %%
DS.describe()
# Out:
#        Number of clicks on similar products  \
# count                           1018.000000
# mean                              21.397839
# std                               12.103449
# min                                0.000000
# 25%                               11.000000
# 50%                               20.000000
# 75%                               31.000000
# max                               55.000000
#
#        Number of similar products purchased so far  \
# count                                  1018.000000
# mean                                      9.017682
# std                                       5.740169
# min                                       0.000000
# 25%                                       4.000000
# 50%                                       8.000000
# 75%                                      14.000000
# max                                      24.000000
#
#        Average rating given to similar products  \
# ...

# %% [markdown]
# Task 8

# %%
DS['Price of the product'].mean().round()
# Out:
# np.float64(1335.0)

# %% [markdown]
# task 9

# %%
DS['Median purchasing price (in rupees)'].max()
# Out:
# 19000

# %%
DS['Median purchasing price (in rupees)'].min()
# Out:
# 100

# %%
DS.columns
# Out:
# Index(['Number of clicks on similar products',
#        'Number of similar products purchased so far',
#        'Average rating given to similar products', 'Gender',
#        'Median purchasing price (in rupees)', 'Rating of the product',
#        'Brand of the product', 'Customer review sentiment score (overall)',
#        'Price of the product', 'Holiday', 'Season', 'Geographical locations',
#        'Probability for the product to be recommended to the person'],
#       dtype='object')

# %% [markdown]
# task 10

# %%
DS['Brand of the product'].value_counts()
# Out:
# Brand of the product
# Wildcraft                          74
# Manyavar Mohey                     58
# Pepperfry                          55
# Flying Machine                     52
# Patanjali Ayurved (Health Care)    50
# Lee                                46
# Lakme Ayurveda                     45
# Wakefit                            41
# Johnson & Johnson                  40
# Khadi Essentials                   34
# Pepe Jeans London                  33
# Kama Ayurveda                      32
# Max                                29
# PUMA                               25
# Head Hunters                       24
# Himalaya Liv.52                    24
# Sugar Cosmetics                    24
# Fastrack                           22
# The Moms Co.                       22
# Dettol                             21
# Urban Ladder                       20
# SleepyCat                          20
# AmazonBasics                       17
# Allen Solly Woman                  16
# ...

# %% [markdown]
# task 11

# %%
DS['Price of the product'].sort_values(ascending=False)
# Out:
# 920     10000
# 1404    10000
# 1431    10000
# 851     10000
# 1444    10000
#         ...
# 37        100
# 84        100
# 764        90
# 788        90
# 752        90
# Name: Price of the product, Length: 1018, dtype: int64

# %% [markdown]
# task 12

# %%
DS.loc[DS['Rating of the product']> 4]
# Out:
#       Number of clicks on similar products  \
# 0                                       12
# 2                                       25
# 4                                       18
# 6                                       38
# 9                                       10
# ...                                    ...
# 1467                                    43
# 1468                                    21
# 1470                                    37
# 1471                                    22
# 1472                                    40
#
#       Number of similar products purchased so far  \
# 0                                               4
# 2                                              10
# 4                                               5
# 6                                              15
# 9                                               4
# ...                                           ...
# 1467                                           14
# ...

# %% [markdown]
# task 13

# %%
DS['Price Difference'] = DS['Price of the product']-DS['Median purchasing price (in rupees)']

# %%
DS
# Out:
#       Number of clicks on similar products  \
# 0                                       12
# 1                                        8
# 2                                       25
# 3                                        6
# 4                                       18
# ...                                    ...
# 1469                                     5
# 1470                                    37
# 1471                                    22
# 1472                                    40
# 1473                                    12
#
#       Number of similar products purchased so far  \
# 0                                               4
# 1                                               2
# 2                                              10
# 3                                               1
# 4                                               5
# ...                                           ...
# 1469                                            1
# ...

# %% [raw]
# task 14

# %%
DS.groupby('Gender')['Price of the product'].mean()
# Out:
# Gender
# female     783.638171
# male      1873.359223
# Name: Price of the product, dtype: float64

# %% [markdown]
# task 15

# %%
DS['Price of the product'].value_counts().plot(kind='hist')
plt.show()

# %% [markdown]
# Ans 1 : There was no missing data and data is not 100% accurate we need to clean it furthere for perfect result.

# %% [markdown]
# Ans 2 : Number of clicks on similar products , Number of similar products purchased so far and Average rating given to similar products

# %% [markdown]
# Ans 3: Data was complete given there was some duplicates but but filtering it more we can get accurate result eaily and price difference is flucating
# to much we need to filter it more for better results.
