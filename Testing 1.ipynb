# %%
print("Hello World Again");
# Out:
# Hello World Again

# %%
a = 53

# %%
b = 54

# %%
c = 65

# %%
d = "Fizza"

# %%
e = "calling"

# %%
f = "is"

# %%
g = 5

# %%
a = 53;
b = 54;
c = 65;
d = "Fizza";
e = "calling";
f = "is"
g = 5;
h = " "

print(a*b)
print(g*f)
print(a+b)
print(d+h+f+h+e)
print(b/5)
print(d+h+"is"+h+e)


type (15.5)
int ('154')
print(a%g)
# Out:
# 2862
# isisisisis
# 107
# Fizza is calling
# 10.8
# Fizza is calling
# 3
