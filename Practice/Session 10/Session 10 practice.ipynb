# %%
import pandas as pd

# %%
import numpy as np

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
import matplotlib as mp
import matplotlib.pyplot as plt

# %%
ds = pd.read_csv('cars.csv')

# %%
ds
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
ds.describe
# Out:
# <bound method NDFrame.describe of           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
ds.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
ds.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
ds.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
ds['Engine Fuel Type'].fillna(ds['Engine Fuel Type'].mode()[0],inplace=True)

# %%
ds.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        0
# Engine HP               0
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         0
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
ds['Engine HP'].fillna(ds['Engine HP'].median(),inplace=True)

# %%
ds['Number of Doors'].fillna(ds['Number of Doors'].mode()[0],inplace=True)

# %%
ds['Engine Cylinders'].mode()
# Out:
# 0    4.0
# Name: Engine Cylinders, dtype: float64

# %%
ds['Engine Cylinders'].fillna(ds['Engine Cylinders'].mode()[0],inplace=True)

# %%
ds.isnull().sum()
# Out:
# Make                 0
# Model                0
# Year                 0
# Engine Fuel Type     0
# Engine HP            0
# Engine Cylinders     0
# Transmission Type    0
# Driven_Wheels        0
# Number of Doors      0
# Vehicle Size         0
# Vehicle Style        0
# highway MPG          0
# city mpg             0
# Popularity           0
# MSRP                 0
# dtype: int64

# %%
ds.drop(columns=['Market Category'],inplace=True)

# %%
 ds.duplicated().sum()
# Out:
# np.int64(720)

# %%
ds.drop_duplicates()
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
ds = ds.drop_duplicates().sum()

# %%
ds.duplicated().sum()
# Out:
# np.int64(0)

# %%
ds['']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 ds.dtypes()
#
# TypeError: 'numpy.dtypes.ObjectDType' object is not callable

# %%
ds.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17732\1656581057.py in ?()
# ----> 1 ds.columns
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
ds.columns()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17732\1736746980.py in ?()
# ----> 1 ds.columns()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
ds
# Out:
# Make                 BMWBMWBMWBMWBMWBMWBMWBMWBMWBMWBMWBMWBMWBMWBMWB...
# Model                1 Series M1 Series1 Series1 Series1 Series1 Se...
# Year                                                          22507944
# Engine Fuel Type     premium unleaded (required)premium unleaded (r...
# Engine HP                                                    2834633.0
# Engine Cylinders                                               63373.0
# Transmission Type    MANUALMANUALMANUALMANUALMANUALMANUALMANUALMANU...
# Driven_Wheels        rear wheel driverear wheel driverear wheel dri...
# Number of Doors                                                38668.0
# Vehicle Size         CompactCompactCompactCompactCompactCompactComp...
# Vehicle Style        CoupeConvertibleCoupeCoupeConvertibleCoupeConv...
# highway MPG                                                     297875
# city mpg                                                        220881
# ...

# %%
ds.describe
# Out:
# <bound method NDFrame.describe of Make                 BMWBMWBMWBMWBMWBMWBMWBMWBMWBMWBMWBMWBMWBMWBMWB...
# Model                1 Series M1 Series1 Series1 Series1 Series1 Se...
# Year                                                          22507944
# Engine Fuel Type     premium unleaded (required)premium unleaded (r...
# Engine HP                                                    2834633.0
# Engine Cylinders                                               63373.0
# Transmission Type    MANUALMANUALMANUALMANUALMANUALMANUALMANUALMANU...
# Driven_Wheels        rear wheel driverear wheel driverear wheel dri...
# Number of Doors                                                38668.0
# Vehicle Size         CompactCompactCompactCompactCompactCompactComp...
# Vehicle Style        CoupeConvertibleCoupeCoupeConvertibleCoupeConv...
# highway MPG                                                     297875
# city mpg                                                        220881
# ...

# %%
ds.isnull().sum()
# Out:
# Make                 0
# Model                0
# Year                 0
# Engine Fuel Type     0
# Engine HP            0
# Engine Cylinders     0
# Transmission Type    0
# Driven_Wheels        0
# Number of Doors      0
# Vehicle Size         0
# Vehicle Style        0
# highway MPG          0
# city mpg             0
# Popularity           0
# MSRP                 0
# dtype: int64

# %%
ds.describe
# Out:
# <bound method NDFrame.describe of           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
ds.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Vehicle Size', 'Vehicle Style', 'highway MPG',
#        'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
ds.Make.value_counts().head(10)
# Out:
# Make
# Chevrolet     1123
# Ford           881
# Volkswagen     809
# Toyota         746
# Dodge          626
# Nissan         558
# GMC            515
# Honda          449
# Mazda          423
# Cadillac       397
# Name: count, dtype: int64

# %%
ds.loc[ds['MSRP'].idxmax(), 'Model'].
# Out:
# 'Veyron 16.4'

# %%
ds.loc[ds['Make'].idxmax()].head()
# Out:
# Make                           Volvo
# Model                            240
# Year                            1991
# Engine Fuel Type    regular unleaded
# Engine HP                      114.0
# Name: 104, dtype: object

# %%
ds.groupby('Make')['MSRP'].mean().sort_vales(ascending = False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17732\810994065.py in ?()
# ----> 1 ds.groupby('Make')['MSRP'].mean().sort_vales(ascending = False)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'sort_vales'

# %%
ds.groupby('Make')['MSRP'].mean().sort_values(ascending=False).round(1).head(10)
# Out:
# Make
# Bugatti         1757223.7
# Maybach          546221.9
# Rolls-Royce      351130.6
# Lamborghini      331567.3
# Bentley          247169.3
# McLaren          239805.0
# Ferrari          238218.8
# Spyker           213323.3
# Aston Martin     197910.4
# Maserati         114207.7
# Name: MSRP, dtype: float64

# %%
ds.groupby('Make')['Engine HP'].mean().sort_values(ascending=False).round().head(10)
# Out:
# Make
# Bugatti         1001.0
# Lamborghini      614.0
# McLaren          610.0
# Maybach          590.0
# Bentley          534.0
# Ferrari          512.0
# Rolls-Royce      488.0
# Aston Martin     484.0
# Maserati         421.0
# Spyker           400.0
# Name: Engine HP, dtype: float64

# %%
ds.Make.value_counts().head(10)
# Out:
# Make
# Chevrolet     1123
# Ford           881
# Volkswagen     809
# Toyota         746
# Dodge          626
# Nissan         558
# GMC            515
# Honda          449
# Mazda          423
# Cadillac       397
# Name: count, dtype: int64

# %%
ds.Make.value_counts().head(10).plot(kind='bar')
plt.show()

# %%
ds.Model.value_counts().head(10).plot(kind='bar')
plt.show()

# %%
ds.VehicleSize.value_counts().head(10).plot(kind='bar')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17732\1254618649.py in ?()
# ----> 1 ds.VehicleSize.value_counts().head(10).plot(kind='bar')
#       2 plt.show()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'VehicleSize'

# %%
ds.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Vehicle Size', 'Vehicle Style', 'highway MPG',
#        'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
ds.Make.value_counts().head(100).plot(kind='line')
plt.show()

# %%
ds.
