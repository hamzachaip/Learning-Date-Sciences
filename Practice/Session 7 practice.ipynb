# %%
# OOP
    # class

# %%
class Student:
    def __init__(self,school_name,location): 
        self.Sclname = school_name
        self.loc = location
        print('This is school name and location')
    def greet(self,Name,Age,City):
        self.name = Name
        self.age = Age
        self.city = City
        return print('Welcome')
    def sub(self):
        return print('OOP')

# %%
std = Student('Haseeb Public School','Karachi')
# Out:
# This is school name and location

# %%
std.greet('Hamza',25,'karachi')
# Out:
# Welcome

# %%
std.name
# Out:
# 'Hamza'

# %%
Sname = input('Enter you name')
Sage = int(input('Enter your age'))
City = input('Enter your city')

std.greet(Sname,Sage,City)
# Out:
# Enter you name Hamza
# Enter your age 25
# Enter your city Karachi
# Welcome
