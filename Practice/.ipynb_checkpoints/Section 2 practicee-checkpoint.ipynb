# %%
x = 10
# > Greater then
# < Lesss then
# >= 
# <=
# ==
# !=
if x < 5:
    print( True)
else:
    print( False)
# Out:
# False

# %%
# Three conditions
x = 9
if x == 10:
    print("it's equal to 9")
elif x != 9:
    print ("it's not equal to 9")
elif x >1:
    print( "9 greater then 1")
else:
    print("log out")
# Out:
# 9 greater then 1

# %%
# Logical Operators
# And
# or 
# Not
Username = input("Username")
Age = int(input("Age"))
a = 'ali'
b = 18
c = 'Hamza'
d = 25
if Username == a and Age >= b:
    print('Login')
elif Username == c and Age >= d:
    print('You are Admin Hamza')
else: 
    print('Logout')
# Out:
# Username ali
# Age 19
# Login

# %%
# Logical Operators
# And
# or 
# Not
Username = input("Username")
Age = int(input("Age"))
a = 'ali'
b = 18
c = 'Hamza'
d = 25
if Username == a and Age >= b:
    print('Login')
elif Username == c or Age >= d:
    print('You are Admin Hamza')
else: 
    print('Logout')
# Out:
# Username Hamza
# Age 26
# You are Admin Hamza

# %%
Name = input('Name')
Eng = int(input ('English'))
Urdu = int(input ('Urdu'))
Math = int(input ('Math'))
Computer = int(input ('Computer'))
Sci = int(input ('Science'))
PST = int(input ('Pakistan Studies'))
Total= Eng+Urdu+Math+Computer+Sci+PST
print(Total)
Perc = Total/600*100
print(Perc)


if Perc > 100:
    print('Cheater')
elif Perc >= 80  :
    print('A+')
elif Perc >= 70:
    print('A')
elif Perc >= 60:
    print('B')
elif Perc >= 50:
    print('C')
elif Perc < 50:
    print('Fail')
else:
    print('Error')
# Out:
# Name Hamza
# English 55
# Urdu 55
# Math 55
# Computer 55
# Science 55
# Pakistan Studies 55
# 330
# 55.00000000000001
# C

# %%
# List
Names=['Ali','Farhan','Daniyal','Ali']
print(Names[2])
# Out:
# Daniyal

# %%
# Indexing
Salries=['30k','100k','200k','','300k','','450k']
Salriesint=[100,33,33,56,32,45,33,23,23]
Salries
print(Salries[1])
Salries[2]
Salries[1:4]
Salries[-7:-2:2]

dir(list)

Employess=['Ali','Usman','Hamza','Hamza','Hamza','Daniyal','Faizan','Usman','Ali']
Employess
Salriesint
# Out:
# 100k
# [100, 33, 33, 56, 32, 45, 33, 23, 23]

# %%
Employess
Salries
Salriesint
# Out:
# [100, 33, 33, 56, 32, 45, 33, 23, 23]

# %%
dir([])
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
Employess.append('Naeem')

# %%
Employess
EmployessCopy = Employess.copy()
EmployessCopy
# Out:
# ['Ali',
#  'Usman',
#  'Hamza',
#  'Hamza',
#  'Hamza',
#  'Daniyal',
#  'Faizan',
#  'Usman',
#  'Ali',
#  'Naeem']

# %%
EmployessCopy.count('Ali')
# Out:
# 2

# %%
EmployessCopy.extend(Salries)

# %%
EmployessCopy
# Out:
# ['Ali',
#  'Usman',
#  'Hamza',
#  'Hamza',
#  'Hamza',
#  'Daniyal',
#  'Faizan',
#  'Usman',
#  'Ali',
#  'Naeem',
#  '30k',
#  '100k',
#  '200k',
#  '',
#  '300k',
#  '',
#  '450k']

# %%
EmployessCopy.index('Ali')

EmployessCopy.insert(5,'Bread')

# %%
EmployessCopy
# Out:
# ['Ali',
#  'Usman',
#  'Hamza',
#  'Hamza',
#  'Hamza',
#  'Bread',
#  'Daniyal',
#  'Faizan',
#  'Usman',
#  'Ali',
#  'Naeem',
#  '30k',
#  '100k',
#  '200k',
#  '',
#  '300k',
#  '',
#  '450k']

# %%
EmployessCopy.pop(10)
# Out:
# 'Naeem'

# %%
EmployessCopy.remove('Hamza')

# %%
EmployessCopy
# Out:
# ['Ali',
#  'Usman',
#  'Hamza',
#  'Hamza',
#  'Bread',
#  'Daniyal',
#  'Faizan',
#  'Usman',
#  'Ali',
#  '30k',
#  '100k',
#  '200k',
#  '',
#  '300k',
#  '',
#  '450k']

# %%
Salriesint.sort()
Salriesint
# Out:
# [23, 23, 32, 33, 33, 33, 45, 56, 100]

# %%
0
