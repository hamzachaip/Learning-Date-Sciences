# %%
Studen_data={
    1:{'Roll Number':int(input('Roll number')),'Name':input('Entername').capitalize(),'Age':int(input('Enter age')),'English':int(input('English marks')),'Urdu':int(input('Urdu Marks')),'Math':int(input('Math Marks'))}
}
# Out:
# Roll number 100
# Entername Hamza
# Enter age 25
# English marks 52
# Urdu Marks 45
# Math Marks 55

# %%
while True:
    Roll_Number=input("Enter name (or exit): ")
    if Roll_Number.lower() == 'exit':
    break

    Studen_data[Seriol_number]={
        'Roll Number':int(input('Roll number')),
        'Name':input('Entername').capitalize(),
        'Age':int(input('Enter age')),
        Marks:[
            int(input("English: ")),
            int(input("Urdu: ")),
            int(input("Math: "))
        ]
        
    }
    student_id += 1

    print(Studen_data)
# Out:
#   Cell In[16], line 4
#     break
#     ^
# IndentationError: expected an indented block after 'if' statement on line 3

# %%
Studen_data.clear()
